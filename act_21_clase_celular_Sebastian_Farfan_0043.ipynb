# %% [markdown]
# <a href="https://colab.research.google.com/github/sebastianfarfan128/ACT-21-Clase-celulares-Python-fecha-22-Abril-2026/blob/main/act_21_clase_celular_Sebastian_Farfan_0043.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Sebastian Farfan NL = 16 Fecha 22/Abr/2026
# ## Clase celular
#
# ![](https://raw.githubusercontent.com/sebastianfarfan128/ACT-21-Clase-celulares-Python-fecha-22-Abril-2026/refs/heads/main/infoClaseCelular.png)

# %%
class Celular:
    def __init__(self, marca, modelo, precio):
        self.marca = marca
        self.modelo = modelo
        self.precio = precio
        self.encendido = False

    def encender(self):
        self.encendido = True
        print(f"El {self.modelo} se ha encendido.")

    def mostrar_info(self):
        print(f"Celular: {self.marca} {self.modelo}, Precio: ${self.precio}")

# Instanciación
cel1 = Celular("Samsung", "Galaxy S23", 800)
cel2 = Celular("Apple", "Iphone 15", 1000)
# llamadas a las funciones para cada objeto celular 1 y celular 2
print("Celular 1:")
cel1.mostrar_info()
cel1.encender()

print("\nCelular 2:")
cel2.mostrar_info()
cel2.encender()

print("programa terminado")
print("Creador de software por Sebastian Farfan NL = 16")
# Out:
# Celular 1:
# Celular: Samsung Galaxy S23, Precio: $800
# El Galaxy S23 se ha encendido.
#
# Celular 2:
# Celular: Apple Iphone 15, Precio: $1000
# El Iphone 15 se ha encendido.
# programa terminado
# Creador de software por Sebastian Farfan NL = 16

# %% [markdown]
# ![texto del vínculo](https://raw.githubusercontent.com/sebastianfarfan128/ACT-21-Clase-celulares-Python-fecha-22-Abril-2026/refs/heads/main/LogicaFuncionamiento.png)
